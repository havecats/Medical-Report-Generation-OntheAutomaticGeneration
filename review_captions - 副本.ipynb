# %%
import json
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
trainresnet152_json = './result_logs/20230412-2254trainresnet152/results/debug.json'
image_dir = './data/images'
debugdensenet201_json = './result_logs/20230406-2027debugdensenet201/results/debug.json'

with open(trainresnet152_json, 'r') as f:
    data = json.load(f)
with open(trainresnet152_json, 'r') as f2:
    data_densenet = json.load(f2)

# %%
def show_image(image_id):
    image = mpimg.imread(os.path.join(image_dir, image_id))
    plt.imshow(image)
    plt.axis('off')
    plt.show()

def get_real_tags(item):
    array = []
    for each in item['Real Tags']:
        if each in item['Pred Tags']:
            array.append("\033[4;35m{}\033[0m".format(each))
        else:
            array.append(each)
    return ', '.join(array)

def get_pred_tags(item):
    return ', '.join(item['Pred Tags'])

def get_sentence(item):
    real_sents = []
    pred_sents = []
    for i in range(max(len(item['Real Sent']), len(item['Pred Sent']))):
#         print("Sentence {}:".format(i))
        try:
            real_sent = item['Real Sent'][str(i)]
        except Exception as _:
            real_sent = ""
        try:
            pred_sent = item['Pred Sent'][str(i)]
        except Exception as _:
            pred_sent = ""
        
#         print("Real: {}".format(real_sent))
#         print("Pred: {}".format(pred_sent))
#         print("")
        real_sents.append(real_sent)
        pred_sents.append(pred_sent)
    print("Real Sents:{}".format(". ".join(real_sents)))
    print("Pred Sents:{}".format('. '.join(pred_sents)))

def get_tags_peformance(data):
    num_ground_truth = 0
    num_pred_all = 0
    num_pred_truth = 0
    for each in data:
        num_ground_truth += len(data[each]['Real Tags'])
        num_pred_all += len(data[each]['Pred Tags'])
        for tag in data[each]['Pred Tags']:
            if tag in data[each]['Real Tags']:
                num_pred_truth += 1
    return num_pred_truth / num_ground_truth * 1.0, num_pred_truth / num_pred_all * 1.0

# %% [markdown]
# ## Image id:

# %%
images_id = []
for each in data:
    print(each)
    images_id.append(each)
# Out:
# CXR1018_IM-0014-5001.png
# CXR1018_IM-0014-6001.png
# CXR1027_IM-0021-1001.png
# CXR1027_IM-0021-2001.png
# CXR1030_IM-0024-1001.png
# CXR1030_IM-0024-2001.png
# CXR1039_IM-0030-1002.png
# CXR1046_IM-0036-1001.png
# CXR1046_IM-0036-2001.png
# CXR1052_IM-0040-1001.png
# CXR1052_IM-0040-1002.png
# CXR1063_IM-0044-84654001.png
# CXR1063_IM-0044-84654002.png
# CXR1065_IM-0046-2001.png
# CXR1074_IM-0054-1001.png
# CXR1074_IM-0054-2001.png
# CXR1092_IM-0063-1001.png
# CXR1092_IM-0063-2001.png
# CXR1101_IM-0068-1001.png
# CXR1101_IM-0068-2001.png
# CXR1101_IM-0068-3001.png
# CXR1138_IM-0094-1001.png
# CXR1138_IM-0094-2001.png
# CXR1147_IM-0099-4004.png
# CXR114_IM-0096-1001.png
# CXR114_IM-0096-2001.png
# CXR1157_IM-0106-1001.png
# CXR1157_IM-0106-2001.png
# CXR1158_IM-0107-1001.png
# CXR1158_IM-0107-2001.png
# CXR1176_IM-0119-1001.png
# CXR1176_IM-0119-2001.png
# CXR1207_IM-0140-0001-0001.png
# CXR1207_IM-0140-0001-0002.png
# CXR1210_IM-0142-1001.png
# CXR786_IM-2326-1001.png
# CXR793_IM-2330-1001.png
# CXR793_IM-2330-2001.png
# CXR80_IM-2333-1001.png
# CXR80_IM-2333-2001.png
# CXR80_IM-2333-3001.png
# CXR810_IM-2343-1001.png
# CXR810_IM-2343-2001.png
# CXR836_IM-2360-1001.png
# CXR836_IM-2360-2001.png
# CXR863_IM-2383-1001.png
# CXR863_IM-2383-2001.png
# CXR863_IM-2383-3001.png
# CXR905_IM-2410-0001-0001.png
# CXR905_IM-2410-0001-0002.png
# CXR936_IM-2432-1001.png
# CXR946_IM-2441-1001.png
# CXR946_IM-2441-2001.png
# CXR957_IM-2449-1001.png
# CXR957_IM-2449-2001.png
# CXR970_IM-2460-2001.png
# CXR970_IM-2460-3001.png
# CXR99_IM-2476-1001.png
# CXR99_IM-2476-1002.png

# %%
recall, precision = get_tags_peformance(data)
print("Recall:{}".format(recall))
print("Precision:{}".format(precision))
# Out:
# Recall:0.5916666666666667
# Precision:0.11759834368530021

# %% [markdown]
# ## Preview

# %%
def show_info(id):
    image_id = images_id[id]
    item = data[image_id]
    print("Image:{}".format(image_id))
    # show_image(image_id)

    print("Real Tags: {}".format(get_real_tags(item)))
    print("Pred Tags: {}".format(get_pred_tags(item)))
    print("")
    get_sentence(item)

# %%
show_info(1)
# Out:
# Image:CXR1018_IM-0014-6001.png
# Real Tags: normal
# Pred Tags: normal, calcified granuloma, degenerative change, granuloma, nodule, others, opacity, granulomatous disease, scarring, pneumonia
#
# Real Sents:no acute cardiopulmonary abnormality. the cardiomediastinal silhouette and pulmonary vasculature are within normal limits. there is no pneumothorax or pleural effusion. there are no focal areas of consolidation. there are small calcified granulomata in the right lateral <unk>. .
# Pred Sents:the heart is normal in size. the lungs are clear. no pneumothorax or pleural effusion. . . .

# %%
show_info(20)
# Out:
# Image:CXR1101_IM-0068-3001.png
# Real Tags: degenerative change
# Pred Tags: normal, degenerative change, opacity, others, cardiomegaly, calcified granuloma, atelectases, atelectasis, granuloma, scarring
#
# Real Sents:no acute cardiopulmonary disease. the heart pulmonary xxxx and mediastinum are within normal limits. there is no pleural effusion or pneumothorax. there is no focal air space opacity to suggest a pneumonia. there are degenerative changes of the <unk>. .
# Pred Sents:the heart is normal in size. the lungs are clear. no pneumothorax or pleural effusion. no acute bony <unk>. . .

# %%
show_info(40)
# Out:
# Image:CXR1233_IM-0157-1001.png
# Real Tags: scarring, cardiomegaly, atelectasis, atelectases
# Pred Tags: normal, cardiomegaly, degenerative change, opacity, others, atelectases, atelectasis, calcified granuloma, scarring, pleural effusion
#
# Real Sents:cardiomegaly without heart failure. minimal xxxx left basilar scarringatelectasis. enlarged cardiomediastinal silhouette. low lung volumes. relative elevation of right hemidiaphragm. xxxx left base density.
# Pred Sents:the lungs are clear. no acute bony <unk>. . . . .

# %%
show_info(60)
# Out:
# Image:CXR1346_IM-0224-4001.png
# Real Tags: catheters, degenerative change
# Pred Tags: normal, degenerative change, calcified granuloma, opacity, others, atelectases, cardiomegaly, granuloma, atelectasis, nodule
#
# Real Sents:right chest xxxx catheter tip at cavoatrial junction. grossly clear lungs. there is a right chest xxxx with catheter tip at the cavoatrial junction. heart size is at the upper limits of normal. lungs are grossly clear. no pleural effusion or pneumothorax.
# Pred Sents:no acute cardiopulmonary abnormality. the lungs are clear. no focal airspace consolidation. no pneumothorax or pleural effusion. . .

# %%
show_info(80)
# Out:
# Image:CXR145_IM-0290-2001.png
# Real Tags: pleural effusions, pleural effusion, infiltrates
# Pred Tags: cardiomegaly, atelectases, atelectasis, opacity, normal, others, pleural effusion, degenerative change, pleural effusions, diaphragm
#
# Real Sents:large right pleural effusion and patchy left lower lobe airspace disease. right costophrenic xxxx is blunted. in the left lower lobe a patchy infiltrate is present. the pulmonary xxxx are <unk>. . .
# Pred Sents:the heart is normal in size. the lungs are clear. no pneumothorax or pleural effusion. no acute bony <unk>. . .

# %%
show_info(52)
# Out:
# Image:CXR1326_IM-0210-0001-0001.png
# Real Tags: central venous catheter, pneumothorax, diaphragm, opacity, central venous catheters, degenerative change
# Pred Tags: normal, degenerative change, others, calcified granuloma, opacity, cardiomegaly, atelectases, atelectasis, scarring, granuloma
#
# Real Sents:stable right-sided subclavian central venous catheter with tip approximating the svc. stable right suprahilar opacity compatible with history of right upper lobe mass. elevation of the right hemidiaphragm. right-sided pneumothorax noted measuring approximately 8 cm from the the right apex. stable postsurgical changes left axilla. degenerative changes thoracic spine.
# Pred Sents:the heart is normal in size. no focal airspace consolidation. no acute bony <unk>. . . .

# %%
def show_info_densenet(id):
    image_id = images_id[id]
    item = data_densenet[image_id]
    print("Image:{}".format(image_id))
    # show_image(image_id)

    print("Real Tags: {}".format(get_real_tags(item)))
    print("Pred Tags: {}".format(get_pred_tags(item)))
    print("")
    get_sentence(item)

# %%
show_info_densenet(0)
# Out:
# Image:CXR1018_IM-0014-5001.png
# Real Tags: normal
# Pred Tags: normal, degenerative change, calcified granuloma, granuloma, opacity, others, granulomatous disease, nodule, scarring, cardiomegaly
#
# Real Sents:no acute cardiopulmonary abnormality. the cardiomediastinal silhouette and pulmonary vasculature are within normal limits. there is no pneumothorax or pleural effusion. there are no focal areas of consolidation. there are small calcified granulomata in the right lateral <unk>. .
# Pred Sents:no acute cardiopulmonary abnormality. the heart is normal in size. the heart and lungs have xxxx xxxx in the interval. the heart is normal in size. the heart is normal in size. the lungs are clear.

# %%
show_info_densenet(15)
# Out:
# Image:CXR1074_IM-0054-2001.png
# Real Tags: normal
# Pred Tags: normal, cardiomegaly, atelectases, atelectasis, opacity, degenerative change, pleural effusion, others, infiltrates, pleural effusions
#
# Real Sents:low lung volumes. no acute cardiopulmonary findings. the cardiomediastinal silhouette is stable. lung volumes remain low. there is no pleural line to suggest pneumothorax or costophrenic xxxx blunting to suggest large pleural effusion. bony structures are within normal <unk>.
# Pred Sents:no acute cardiopulmonary abnormality. no acute cardiopulmonary abnormality. the heart and lungs have xxxx xxxx in the interval. the heart and lungs have xxxx xxxx in the interval. the heart and lungs have xxxx xxxx in the interval. the heart and lungs have xxxx xxxx in the interval.
